# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Módulo 10 atividade 1

# %% [markdown]
# Uma instituição financeira quer conhecer melhor o perfil de renda de seus novos clientes para diversos fins, por exemplo, melhor dimensionar o limite de cartões de crédito dos novos clientes, sem necessariamente solicitar olerites ou documentações que impactem na experiência do seu cliente.
#
# Para isto, conduziu um estudo com alguns clientes, comprovando suas rendas através de olerites e outros documentos, e pretende construir um modelo preditivo para esta renda com base em algumas variáveis que já possui em seu banco de dados.
#
# As variáveis são intuitivas - note que há uma variável 'index' que é um identificador do cliente e que em geral o ```read_csv``` do pandas coloca também uma variável sequencial.
#
# Estes dados estão no arquivo ```previsao_de_renda.csv```. Carregue-o em um *dataframe*.
#
# 1) Avalie a estrutura de correlação das variáveis quantitativas através de um gráfico de "matriz de dispersão" e através da avaliação gráfica da matriz de correlações. Veja se você identifica algum padrão interessante ou que te faça sentido.

# %%
df = pd.read_csv("previsao_de_renda.csv").drop('Unnamed: 0', axis=1).drop_duplicates()
df_continuas = df[['qtd_filhos', 'idade', 'tempo_emprego', 'qt_pessoas_residencia', 'renda']]

# %%
sns.pairplot(df_continuas)

# %%
df_continuas.corr()
# Out:
#                        qtd_filhos     idade  tempo_emprego  \
# qtd_filhos               1.000000 -0.368619      -0.074090
# idade                   -0.368619  1.000000       0.322335
# tempo_emprego           -0.074090  0.322335       1.000000
# qt_pessoas_residencia    0.895710 -0.342854      -0.064750
# renda                    0.009206  0.042837       0.394918
#
#                        qt_pessoas_residencia     renda
# qtd_filhos                          0.895710  0.009206
# idade                              -0.342854  0.042837
# tempo_emprego                      -0.064750  0.394918
# qt_pessoas_residencia               1.000000  0.020118
# renda                               0.020118  1.000000

# %%
sns.clustermap(df_continuas.corr(), center=0)

# %% [markdown]
# 2) Avalie um gráfico de dispersão (*scatterplot*) específico para as duas variáveis mais correlacionadas com *renda*.

# %%
sns.scatterplot(data=df_continuas, x='tempo_emprego', y='renda')
# Out:
# <AxesSubplot:xlabel='tempo_emprego', ylabel='renda'>

# %%
sns.scatterplot(data=df_continuas, x='idade', y='renda')
# Out:
# <AxesSubplot:xlabel='idade', ylabel='renda'>

# %% [markdown]
# 3) Na su aopinião, há outliers na variável renda?

# %% [markdown]
# Sim. Há dois valores acima de 60.000.

# %% [markdown]
# 4) Calcule o logaritmo da variável renda e repita a sequência de análise

# %%
df_continuas['log_renda'] = np.log(df_continuas['renda'])

# %%
sns.scatterplot(data=df_continuas, x='tempo_emprego', y='log_renda')
# Out:
# C:\Users\nerdm\AppData\Local\Temp\ipykernel_11236\2552289241.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_continuas['log_renda'] = np.log(df_continuas['renda'])
# <AxesSubplot:xlabel='tempo_emprego', ylabel='log_renda'>

# %%
sns.scatterplot(data=df_continuas, x='idade', y='log_renda')
# Out:
# <AxesSubplot:xlabel='idade', ylabel='log_renda'>

# %% [markdown]
# 5) A aplicação do LOG você acha que melhorou ou piorou a análise?

# %%
Melhorou. Agora está mais clara a correlação entre o tempo de emprego e a renda do cliente.
